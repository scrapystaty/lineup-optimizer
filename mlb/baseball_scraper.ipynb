# %%
from baseball_scraper import statcast

# %%
statcast('2023-04-06', '2023-04-07')
# Out:
#       index pitch_type  game_date  release_speed  release_pos_x  \
# 0      3094         SL 2023-04-07           79.2          -2.18
# 1      3235         FF 2023-04-07           93.4          -2.09
# 2      3346         FF 2023-04-07           93.4          -2.08
# 3      3483         FC 2023-04-07           87.9          -2.29
# 4      3635         CH 2023-04-07           85.3          -2.51
# ...     ...        ...        ...            ...            ...
# 6082   5838         FF 2023-04-06           96.9          -1.94
# 6083   5931         SL 2023-04-06           85.8          -1.98
# 6084   5965         FF 2023-04-06           98.1          -1.92
# 6085   6000         FF 2023-04-06           96.6          -1.93
# 6086   6037         FF 2023-04-06           97.1          -1.92
#
#       release_pos_z       player_name    batter   pitcher  \
# 0              5.61      Reyes, Denyi  663743.0  660593.0
# 1              5.78      Reyes, Denyi  663743.0  660593.0
# ...
