# %%
import pandas as pd

# %%
df = pd.read_excel(r"/Users/ericmartinez/Documents/nbaStatsExample/nbaStatsExample2023-24.xlsx")

# %%
df
# Out:
#      Unnamed: 0            PLAYER TEAM  AGE  GP   W   L   MIN  OFFRTG  DEFRTG  \
# 0             0    Andre Drummond  CHI   30  43  20  23  15.9   110.5   112.8
# 1             1     Austin Reaves  LAL   25  43  21  22  30.2   111.9   116.7
# 2             2   Christian Braun  DEN   22  43  29  14  19.1   108.1   111.1
# 3             3        Coby White  CHI   23  43  20  23  35.5   114.2   114.6
# 4             4     Collin Sexton  UTA   25  43  22  21  23.8   117.1   117.3
# ..          ...               ...  ...  ...  ..  ..  ..   ...     ...     ...
# 523         523   Malcolm Cazalon  DET   22   1   0   1   2.6   183.3   100.0
# 524         524   Markquis Nowell  TOR   24   1   0   1   3.5   128.6    62.5
# 525         525     Onuralp Bitim  CHI   24   1   0   1   3.2    71.4   116.7
# 526         526    Ron Harper Jr.  TOR   23   1   1   0   3.7   100.0   188.9
# 527         527  Terquavion Smith  PHI   21   1   1   0   1.8   183.3   180.0
#
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0         AGE          GP           W           L         MIN  \
# count   528.00000  528.000000  528.000000  528.000000  528.000000  528.000000
# mean    263.50000   25.791667   25.314394   12.600379   12.714015   18.388826
# std     152.56474    4.340158   13.259475    8.711557    7.954784   10.412852
# min       0.00000   19.000000    1.000000    0.000000    0.000000    0.700000
# 25%     131.75000   23.000000   14.000000    5.000000    7.000000    9.200000
# 50%     263.50000   25.000000   29.000000   12.000000   12.000000   17.550000
# 75%     395.25000   28.000000   38.000000   20.000000   18.000000   27.425000
# max     527.00000   39.000000   43.000000   32.000000   38.000000   37.500000
#
#            OFFRTG      DEFRTG      NETRTG        AST%  ...       OREB%  \
# count  528.000000  528.000000  528.000000  528.000000  ...  528.000000
# mean   109.434470  112.304545   -2.871780   14.388447  ...    4.679545
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  528 non-null    int64
#  1   PLAYER      528 non-null    object
#  2   TEAM        528 non-null    object
#  3   AGE         528 non-null    int64
#  4   GP          528 non-null    int64
#  5   W           528 non-null    int64
#  6   L           528 non-null    int64
#  7   MIN         528 non-null    float64
#  8   OFFRTG      528 non-null    float64
#  9   DEFRTG      528 non-null    float64
#  10  NETRTG      528 non-null    float64
#  11  AST%        528 non-null    float64
#  12  AST/TO      528 non-null    float64
#  13  AST RATIO   528 non-null    float64
#  14  OREB%       528 non-null    float64
#  15  DREB%       528 non-null    float64
#  16  REB%        528 non-null    float64
#  17  TO RATIO    528 non-null    float64
#  18  EFG%        528 non-null    float64
# ...

# %%
HardenDF = df[df['PLAYER'] == "James Harden"]

# %%
HardenDF
# Out:
#      Unnamed: 0        PLAYER TEAM  AGE  GP   W   L   MIN  OFFRTG  DEFRTG  \
# 171         171  James Harden  LAC   34  35  23  12  34.0   122.0   113.2
#
#      ...  OREB%  DREB%  REB%  TO RATIO  EFG%   TS%  USG%   PACE   PIE  POSS
# 171  ...    1.0   12.3   6.9      11.0  57.5  64.1  20.1  97.34  13.4  2413
#
# [1 rows x 24 columns]

# %%
HardenDF = HardenDF.drop(HardenDF.columns[[0]], axis=1)

# %%
HardenDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 171 to 171
# Data columns (total 23 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PLAYER     1 non-null      object
#  1   TEAM       1 non-null      object
#  2   AGE        1 non-null      int64
#  3   GP         1 non-null      int64
#  4   W          1 non-null      int64
#  5   L          1 non-null      int64
#  6   MIN        1 non-null      float64
#  7   OFFRTG     1 non-null      float64
#  8   DEFRTG     1 non-null      float64
#  9   NETRTG     1 non-null      float64
#  10  AST%       1 non-null      float64
#  11  AST/TO     1 non-null      float64
#  12  AST RATIO  1 non-null      float64
#  13  OREB%      1 non-null      float64
#  14  DREB%      1 non-null      float64
#  15  REB%       1 non-null      float64
#  16  TO RATIO   1 non-null      float64
#  17  EFG%       1 non-null      float64
#  18  TS%        1 non-null      float64
# ...
